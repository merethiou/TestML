# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df=pd.read_csv("life.csv")
df
# Out:
#                                 Country  Year  Adult Mortality  infant deaths  \
# 0                           Afghanistan  2015            263.0             62
# 1                               Albania  2015             74.0              0
# 2                               Algeria  2015             19.0             21
# 3                                Angola  2015            335.0             66
# 4                   Antigua and Barbuda  2015             13.0              0
# ..                                  ...   ...              ...            ...
# 178  Venezuela (Bolivarian Republic of)  2015            157.0              9
# 179                            Viet Nam  2015            127.0             28
# 180                               Yemen  2015            224.0             37
# 181                              Zambia  2015             33.0             27
# 182                            Zimbabwe  2015            336.0             22
#
#      percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0                 71.279624         65.0      1154   19.1                  83
# 1                364.975229         99.0         0   58.0                   0
# 2                  0.000000         95.0        63   59.5                  24
# 3                  0.000000         64.0       118   23.3                  98
# 4                  0.000000         99.0         0   47.7                   0
# ..                      ...          ...       ...    ...                 ...
# 178                0.000000         87.0         0   62.1                  10
# 179                0.000000         97.0       256   17.5                  35
# 180                0.000000         69.0       468   41.3                  47
# 181                0.000000          9.0         9   23.4                  40
# 182                0.000000         87.0         0   31.8                  32
#
#      Polio  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0      6.0         65.0        0.1                   17.2
# 1     99.0         99.0        0.1                    1.2
# 2     95.0         95.0        0.1                    6.0
# 3      7.0         64.0        1.9                    8.3
# 4     86.0         99.0        0.2                    3.3
# ..     ...          ...        ...                    ...
# 178   87.0         87.0        0.1                    1.6
# 179   97.0         97.0        0.1                   14.2
# 180   63.0         69.0        0.1                   13.6
# 181    9.0          9.0        4.1                    6.3
# 182   88.0         87.0        6.2                    5.6
#
#       thinness 5-9 years  Income composition of resources  Schooling  Life_exp
# 0                   17.3                            0.479       10.1      65.0
# 1                    1.3                            0.762       14.2      77.8
# 2                    5.8                            0.743       14.4      75.6
# 3                    8.2                            0.531       11.4      52.4
# 4                    3.3                            0.784       13.9      76.4
# ..                   ...                              ...        ...       ...
# 178                  1.5                            0.769       14.3      74.1
# 179                 14.5                            0.678       12.6      76.0
# 180                 13.4                            0.499        9.0      65.7
# 181                  6.1                            0.576       12.5      61.8
# 182                  5.5                            0.507       10.3      67.0
#
# [183 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          183 non-null    object
#  1   Year                             183 non-null    int64
#  2   Adult Mortality                  183 non-null    float64
#  3   infant deaths                    183 non-null    int64
#  4   percentage expenditure           183 non-null    float64
#  5   Hepatitis B                      183 non-null    float64
#  6   Measles                          183 non-null    int64
#  7    BMI                             183 non-null    float64
#  8   under-five deaths                183 non-null    int64
#  9   Polio                            183 non-null    float64
#  10  Diphtheria                       183 non-null    float64
#  11   HIV/AIDS                        183 non-null    float64
#  12   thinness  1-19 years            183 non-null    float64
#  13   thinness 5-9 years              183 non-null    float64
#  14  Income composition of resources  183 non-null    float64
#  15  Schooling                        183 non-null    float64
#  16  Life_exp                         183 non-null    float64
# dtypes: float64(12), int64(4), object(1)
# memory usage: 24.4+ KB

# %%
df.describe().T
# Out:
#                                  count         mean          std       min  \
# Year                             183.0  2015.000000     0.000000  2015.000
# Adult Mortality                  183.0   152.863388    97.561184     1.000
# infant deaths                    183.0    23.803279    83.683762     0.000
# percentage expenditure           183.0     2.383906    27.461032     0.000
# Hepatitis B                      183.0    82.425287    23.407349     6.000
# Measles                          183.0  1502.901639  7842.394928     0.000
#  BMI                             183.0    42.754144    20.571730     2.500
# under-five deaths                183.0    31.612022   107.779778     0.000
# Polio                            183.0    83.207650    24.245778     5.000
# Diphtheria                       183.0    84.633880    22.162793     6.000
#  HIV/AIDS                        183.0     0.660656     1.344702     0.100
#  thinness  1-19 years            183.0     4.534807     4.076838     0.100
#  thinness 5-9 years              183.0     4.575691     4.157750     0.100
# Income composition of resources  183.0     0.691740     0.149138     0.347
# Schooling                        183.0    12.927168     2.831225     4.900
# Life_exp                         183.0    71.616940     8.123706    51.000
#
#                                        25%          50%        75%  \
# Year                             2015.0000  2015.000000  2015.0000
# Adult Mortality                    74.0000   138.000000   213.0000
# infant deaths                       0.0000     2.000000    17.0000
# percentage expenditure              0.0000     0.000000     0.0000
# Hepatitis B                        81.0000    92.000000    97.0000
# Measles                             0.0000    17.000000   202.0000
#  BMI                               24.3000    48.600000    61.3500
# under-five deaths                   0.0000     3.000000    21.0000
# Polio                              83.0000    93.000000    97.0000
# Diphtheria                         83.5000    93.000000    97.0000
#  HIV/AIDS                           0.1000     0.100000     0.4000
#  thinness  1-19 years               1.5000     3.500000     6.5000
#  thinness 5-9 years                 1.5000     3.400000     6.4000
# Income composition of resources     0.5755     0.718000     0.7945
# Schooling                          11.1000    12.927168    14.8500
# Life_exp                           65.7500    73.900000    76.9500
#
#                                           max
# Year                              2015.000000
# Adult Mortality                    484.000000
# infant deaths                      910.000000
# percentage expenditure             364.975229
# Hepatitis B                         99.000000
# Measles                          90387.000000
#  BMI                                77.600000
# under-five deaths                 1100.000000
# Polio                               99.000000
# Diphtheria                          99.000000
#  HIV/AIDS                            9.300000
#  thinness  1-19 years               26.700000
#  thinness 5-9 years                 27.300000
# Income composition of resources      0.948000
# Schooling                           20.400000
# Life_exp                            88.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=df[["Schooling","Income composition of resources","Measles ","Adult Mortality"]]
y=df["Life_exp"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.2 , random_state=667)

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 1.28383677e-01,  3.05934453e+01, -1.16859934e-05, -3.50183968e-02])

# %%
model.intercept_
# Out:
# 53.97815770818329

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=mean_squared_error(y_test,y_pred,squared=False)

print("R2score: ", r2score)
print("mae: ",mae)
print("mse: ",mse)
print("rmse; ",rmse)
# Out:
# R2score:  0.9003117849337103
# mae:  1.9224762478829167
# mse:  6.104840754214323
# rmse;  2.4707975947483685

# %%
import numpy as np

lenght=y_pred.shape[0]
k=np.linspace(0,lenght,lenght)

plt.figure(figsize=(10,7))
plt.plot(k,y_test, label="Reale")
plt.plot(k,y_pred, label="prevista")
plt.legend(loc=2)

# %%
import mlem

mlem.api.save(model,"model_",sample_data=X_train)
# Out:
# MlemModel(location=Location(path='c:/Users/ifoa/Desktop/visual code/TestML/model_.mlem', project=None, rev=None, uri='file://c:/Users/ifoa/Desktop/visual code/TestML/model_.mlem', project_uri=None, fs=<fsspec.implementations.local.LocalFileSystem object at 0x000001491B579BB0>), params={}, artifacts={'data': LocalArtifact(uri='model_', size=629, hash='289f5b037396de1dbdb9e1a1a6c5be12')}, requirements=Requirements(__root__=[InstallableRequirement(module='sklearn', version='1.2.2', package_name='scikit-learn', extra_index=None, source_url=None, vcs=None, vcs_commit=None), InstallableRequirement(module='pandas', version='1.4.2', package_name=None, extra_index=None, source_url=None, vcs=None, vcs_commit=None), InstallableRequirement(module='numpy', version='1.22.3', package_name=None, extra_index=None, source_url=None, vcs=None, vcs_commit=None)]), processors_cache={'model': SklearnModel(model=LinearRegression(), io=SimplePickleIO(), methods={'predict': Signature(name='predict', args=[Argument(name='X', type_=DataFrameType(value=None, columns=['', 'Schooling', 'Income composition of resources', 'Measles ', 'Adult Mortality'], dtypes=['int64', 'float64', 'float64', 'int64', 'float64'], index_cols=['']), required=True, default=None, kw_only=False)], returns=NumpyNdarrayType(value=None, shape=(None,), dtype='float64'), varargs=None, varargs_type=None, varkw=None, varkw_type=None)})}, call_orders={'predict': [('model', 'predict')]})

# %%
new_model=mlem.api.load("model_.mlem")
new_model.predict(X_test)
# Out:
# array([82.297598  , 83.19629282, 73.20388681, 69.15521754, 59.13910362,
#        66.72707936, 73.117616  , 75.33640121, 83.18688595, 62.68957623,
#        76.18973156, 80.99823261, 75.53082927, 62.49808222, 71.93294421,
#        80.77460306, 74.29805903, 61.38711565, 68.35872446, 76.5220499 ,
#        59.99565644, 60.46178276, 72.74770098, 74.66629115, 69.87918718,
#        81.97266786, 57.05368624, 72.03600196, 58.93092356, 80.89854971,
#        64.5494238 , 71.56445355, 59.71217317, 63.50892049, 73.31362744,
#        72.31611968, 60.72591132])
